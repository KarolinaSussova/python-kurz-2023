# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

platy = pd.read_csv("platy_2021_02.csv")

# %%
platy["plat"].hist(bins = range(30000, 60000, 2500))
# Out:
# <Axes: >

# %%
bins = range(30000, 60000, 2500)
sns.histplot(platy, bins = bins, x = "plat")
# Out:
# <Axes: xlabel='plat', ylabel='Count'>
